# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Chi2 veri setini yükleyin
chi2_train_df = pd.read_csv('updated_data/chi_square_train.csv')
chi2_test_df = pd.read_csv('updated_data/chi_square_test.csv')

# Eğitim verileri için öznitelikler ve hedef değişkeni ayırın
X_train = chi2_train_df.drop('diabetes', axis=1)
y_train = chi2_train_df['diabetes']

# Test verileri için öznitelikler ve hedef değişkeni ayırın
X_test = chi2_test_df.drop('diabetes', axis=1)
y_test = chi2_test_df['diabetes']

correlation_train_df = pd.read_csv('updated_data/correlation_train.csv')
correlation_test_df = pd.read_csv('updated_data/correlation_test.csv')

# Eğitim verileri için öznitelikler ve hedef değişkeni ayırın
X_train1 = correlation_train_df.drop('diabetes', axis=1)
y_train1 = correlation_train_df['diabetes']

# Test verileri için öznitelikler ve hedef değişkeni ayırın
X_test1 = correlation_test_df.drop('diabetes', axis=1)
y_test1 = correlation_test_df['diabetes']


# Lasso veri setini yükleyin
lasso_train_df = pd.read_csv('updated_data/rfe_train.csv')
lasso_test_df = pd.read_csv('updated_data/rfe_test.csv')

# Eğitim verileri için öznitelikler ve hedef değişkeni ayırın
X_train2 = lasso_train_df.drop('diabetes', axis=1)
y_train2 = lasso_train_df['diabetes']

# Test verileri için öznitelikler ve hedef değişkeni ayırın
X_test2 = lasso_test_df.drop('diabetes', axis=1)
y_test2 = lasso_test_df['diabetes']

# %%
# Verileri ölçeklendirin
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# KNN modelini oluşturun ve eğitin
knn_model = KNeighborsClassifier(n_neighbors=5)
knn_model.fit(X_train_scaled, y_train)

# Eğitim verileri üzerinde tahmin yapın
y_train_pred = knn_model.predict(X_train_scaled)

# Test verileri üzerinde tahmin yapın
y_test_pred = knn_model.predict(X_test_scaled)

# Performans metriklerini hesaplayın
train_accuracy = accuracy_score(y_train, y_train_pred)
test_accuracy = accuracy_score(y_test, y_test_pred)
train_precision = precision_score(y_train, y_train_pred)
test_precision = precision_score(y_test, y_test_pred)
train_recall = recall_score(y_train, y_train_pred)
test_recall = recall_score(y_test, y_test_pred)
train_f1 = f1_score(y_train, y_train_pred)
test_f1 = f1_score(y_test, y_test_pred)

print(f'KNN - Eğitim Verileri - Accuracy: {train_accuracy}')
print(f'KNN - Eğitim Verileri - Precision: {train_precision}')
print(f'KNN - Eğitim Verileri - Recall: {train_recall}')
print(f'KNN - Eğitim Verileri - F1 Score: {train_f1}')

print(f'KNN - Test Verileri - Accuracy: {test_accuracy}')
print(f'KNN - Test Verileri - Precision: {test_precision}')
print(f'KNN - Test Verileri - Recall: {test_recall}')
print(f'KNN - Test Verileri - F1 Score: {test_f1}')

# Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_test_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Tahmin Edilen')
plt.ylabel('Gerçek')
plt.title('Confusion Matrix - KNN (Chi2)')
plt.show()
# Out:
# KNN - Eğitim Verileri - Accuracy: 0.9783355836504235
# KNN - Eğitim Verileri - Precision: 0.9387550200803213
# KNN - Eğitim Verileri - Recall: 0.4090113735783027
# KNN - Eğitim Verileri - F1 Score: 0.5697745277269958
# KNN - Test Verileri - Accuracy: 0.9747161706044799
# KNN - Test Verileri - Precision: 0.8097165991902834
# KNN - Test Verileri - Recall: 0.35398230088495575
# KNN - Test Verileri - F1 Score: 0.49261083743842365

# %%
# Verileri ölçeklendirin
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train1)
X_test_scaled = scaler.transform(X_test1)

# KNN modelini oluşturun ve eğitin
knn_model = KNeighborsClassifier(n_neighbors=5)
knn_model.fit(X_train_scaled, y_train1)

# Eğitim verileri üzerinde tahmin yapın
y_train_pred = knn_model.predict(X_train_scaled)

# Test verileri üzerinde tahmin yapın
y_test_pred = knn_model.predict(X_test_scaled)

# Performans metriklerini hesaplayın
train_accuracy = accuracy_score(y_train1, y_train_pred)
test_accuracy = accuracy_score(y_test1, y_test_pred)
train_precision = precision_score(y_train1, y_train_pred)
test_precision = precision_score(y_test1, y_test_pred)
train_recall = recall_score(y_train1, y_train_pred)
test_recall = recall_score(y_test1, y_test_pred)
train_f1 = f1_score(y_train1, y_train_pred)
test_f1 = f1_score(y_test1, y_test_pred)

print(f'KNN - Eğitim Verileri - Accuracy: {train_accuracy}')
print(f'KNN - Eğitim Verileri - Precision: {train_precision}')
print(f'KNN - Eğitim Verileri - Recall: {train_recall}')
print(f'KNN - Eğitim Verileri - F1 Score: {train_f1}')

print(f'KNN - Test Verileri - Accuracy: {test_accuracy}')
print(f'KNN - Test Verileri - Precision: {test_precision}')
print(f'KNN - Test Verileri - Recall: {test_recall}')
print(f'KNN - Test Verileri - F1 Score: {test_f1}')

# Confusion Matrix
conf_matrix = confusion_matrix(y_test1, y_test_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Tahmin Edilen')
plt.ylabel('Gerçek')
plt.title('Confusion Matrix - KNN (Correlation)')
plt.show()
# Out:
# KNN - Eğitim Verileri - Accuracy: 0.9807291027372039
# KNN - Eğitim Verileri - Precision: 0.958185053380783
# KNN - Eğitim Verileri - Recall: 0.47112860892388453
# KNN - Eğitim Verileri - F1 Score: 0.6316715542521995
# KNN - Test Verileri - Accuracy: 0.9788892298250997
# KNN - Test Verileri - Precision: 0.9201520912547528
# KNN - Test Verileri - Recall: 0.4283185840707965
# KNN - Test Verileri - F1 Score: 0.5845410628019324

# %%
# Verileri ölçeklendirin
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train2)
X_test_scaled = scaler.transform(X_test2)

# KNN modelini oluşturun ve eğitin
knn_model = KNeighborsClassifier(n_neighbors=5)
knn_model.fit(X_train_scaled, y_train2)

# Eğitim verileri üzerinde tahmin yapın
y_train_pred = knn_model.predict(X_train_scaled)

# Test verileri üzerinde tahmin yapın
y_test_pred = knn_model.predict(X_test_scaled)

# Performans metriklerini hesaplayın
train_accuracy = accuracy_score(y_train2, y_train_pred)
test_accuracy = accuracy_score(y_test2, y_test_pred)
train_precision = precision_score(y_train2, y_train_pred)
test_precision = precision_score(y_test2, y_test_pred)
train_recall = recall_score(y_train2, y_train_pred)
test_recall = recall_score(y_test2, y_test_pred)
train_f1 = f1_score(y_train2, y_train_pred)
test_f1 = f1_score(y_test2, y_test_pred)

print(f'KNN - Eğitim Verileri - Accuracy: {train_accuracy}')
print(f'KNN - Eğitim Verileri - Precision: {train_precision}')
print(f'KNN - Eğitim Verileri - Recall: {train_recall}')
print(f'KNN - Eğitim Verileri - F1 Score: {train_f1}')

print(f'KNN - Test Verileri - Accuracy: {test_accuracy}')
print(f'KNN - Test Verileri - Precision: {test_precision}')
print(f'KNN - Test Verileri - Recall: {test_recall}')
print(f'KNN - Test Verileri - F1 Score: {test_f1}')

# Confusion Matrix
conf_matrix = confusion_matrix(y_test2, y_test_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Tahmin Edilen')
plt.ylabel('Gerçek')
plt.title('Confusion Matrix - KNN (RFE)')
plt.show()
# Out:
# KNN - Eğitim Verileri - Accuracy: 0.9799159199705413
# KNN - Eğitim Verileri - Precision: 0.942883046237534
# KNN - Eğitim Verileri - Recall: 0.4549431321084864
# KNN - Eğitim Verileri - F1 Score: 0.6137503688403659
# KNN - Test Verileri - Accuracy: 0.9776004909481436
# KNN - Test Verileri - Precision: 0.8816793893129771
# KNN - Test Verileri - Recall: 0.4088495575221239
# KNN - Test Verileri - F1 Score: 0.558645707376058

# %%
# Decision Tree modelini oluşturun ve eğitin
tree_model = DecisionTreeClassifier(random_state=42)
tree_model.fit(X_train, y_train)

# Eğitim verileri üzerinde tahmin yapın
y_train_pred = tree_model.predict(X_train)

# Test verileri üzerinde tahmin yapın
y_test_pred = tree_model.predict(X_test)

# Performans metriklerini hesaplayın
train_accuracy = accuracy_score(y_train, y_train_pred)
test_accuracy = accuracy_score(y_test, y_test_pred)
train_precision = precision_score(y_train, y_train_pred)
test_precision = precision_score(y_test, y_test_pred)
train_recall = recall_score(y_train, y_train_pred)
test_recall = recall_score(y_test, y_test_pred)
train_f1 = f1_score(y_train, y_train_pred)
test_f1 = f1_score(y_test, y_test_pred)

print(f'Decision Trees - Eğitim Verileri - Accuracy: {train_accuracy}')
print(f'Decision Trees - Eğitim Verileri - Precision: {train_precision}')
print(f'Decision Trees - Eğitim Verileri - Recall: {train_recall}')
print(f'Decision Trees - Eğitim Verileri - F1 Score: {train_f1}')

print(f'Decision Trees - Test Verileri - Accuracy: {test_accuracy}')
print(f'Decision Trees - Test Verileri - Precision: {test_precision}')
print(f'Decision Trees - Test Verileri - Recall: {test_recall}')
print(f'Decision Trees - Test Verileri - F1 Score: {test_f1}')

# Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_test_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Tahmin Edilen')
plt.ylabel('Gerçek')
plt.title('Confusion Matrix - Decision Trees (Chi2)')
plt.show()
# Out:
# Decision Trees - Eğitim Verileri - Accuracy: 0.999125444949061
# Decision Trees - Eğitim Verileri - Precision: 0.9995517705064993
# Decision Trees - Eğitim Verileri - Recall: 0.9755030621172354
# Decision Trees - Eğitim Verileri - F1 Score: 0.9873810050918751
# Decision Trees - Test Verileri - Accuracy: 0.9658177355016876
# Decision Trees - Test Verileri - Precision: 0.5065573770491804
# Decision Trees - Test Verileri - Recall: 0.5469026548672566
# Decision Trees - Test Verileri - F1 Score: 0.5259574468085106

# %%
# Decision Tree modelini oluşturun ve eğitin
tree_model = DecisionTreeClassifier(random_state=42)
tree_model.fit(X_train1, y_train1)

# Eğitim verileri üzerinde tahmin yapın
y_train_pred = tree_model.predict(X_train1)

# Test verileri üzerinde tahmin yapın
y_test_pred = tree_model.predict(X_test1)

# Performans metriklerini hesaplayın
train_accuracy = accuracy_score(y_train1, y_train_pred)
test_accuracy = accuracy_score(y_test1, y_test_pred)
train_precision = precision_score(y_train1, y_train_pred)
test_precision = precision_score(y_test1, y_test_pred)
train_recall = recall_score(y_train1, y_train_pred)
test_recall = recall_score(y_test1, y_test_pred)
train_f1 = f1_score(y_train1, y_train_pred)
test_f1 = f1_score(y_test1, y_test_pred)

print(f'Decision Trees - Eğitim Verileri - Accuracy: {train_accuracy}')
print(f'Decision Trees - Eğitim Verileri - Precision: {train_precision}')
print(f'Decision Trees - Eğitim Verileri - Recall: {train_recall}')
print(f'Decision Trees - Eğitim Verileri - F1 Score: {train_f1}')

print(f'Decision Trees - Test Verileri - Accuracy: {test_accuracy}')
print(f'Decision Trees - Test Verileri - Precision: {test_precision}')
print(f'Decision Trees - Test Verileri - Recall: {test_recall}')
print(f'Decision Trees - Test Verileri - F1 Score: {test_f1}')

# Confusion Matrix
conf_matrix = confusion_matrix(y_test1, y_test_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Tahmin Edilen')
plt.ylabel('Gerçek')
plt.title('Confusion Matrix - Decision Trees (Correlation)')
plt.show()
# Out:
# Decision Trees - Eğitim Verileri - Accuracy: 0.9967319258622805
# Decision Trees - Eğitim Verileri - Precision: 0.9980778471888515
# Decision Trees - Eğitim Verileri - Recall: 0.9085739282589677
# Decision Trees - Eğitim Verileri - F1 Score: 0.9512250973208152
# Decision Trees - Test Verileri - Accuracy: 0.9675360540042958
# Decision Trees - Test Verileri - Precision: 0.53125
# Decision Trees - Test Verileri - Recall: 0.5415929203539823
# Decision Trees - Test Verileri - F1 Score: 0.5363716038562665

# %%
# Decision Tree modelini oluşturun ve eğitin
tree_model = DecisionTreeClassifier(random_state=42)
tree_model.fit(X_train2, y_train2)

# Eğitim verileri üzerinde tahmin yapın
y_train_pred = tree_model.predict(X_train2)

# Test verileri üzerinde tahmin yapın
y_test_pred = tree_model.predict(X_test2)

# Performans metriklerini hesaplayın
train_accuracy = accuracy_score(y_train2, y_train_pred)
test_accuracy = accuracy_score(y_test2, y_test_pred)
train_precision = precision_score(y_train2, y_train_pred)
test_precision = precision_score(y_test2, y_test_pred)
train_recall = recall_score(y_train2, y_train_pred)
test_recall = recall_score(y_test2, y_test_pred)
train_f1 = f1_score(y_train2, y_train_pred)
test_f1 = f1_score(y_test2, y_test_pred)

print(f'Decision Trees - Eğitim Verileri - Accuracy: {train_accuracy}')
print(f'Decision Trees - Eğitim Verileri - Precision: {train_precision}')
print(f'Decision Trees - Eğitim Verileri - Recall: {train_recall}')
print(f'Decision Trees - Eğitim Verileri - F1 Score: {train_f1}')

print(f'Decision Trees - Test Verileri - Accuracy: {test_accuracy}')
print(f'Decision Trees - Test Verileri - Precision: {test_precision}')
print(f'Decision Trees - Test Verileri - Recall: {test_recall}')
print(f'Decision Trees - Test Verileri - F1 Score: {test_f1}')

# Confusion Matrix
conf_matrix = confusion_matrix(y_test2, y_test_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Tahmin Edilen')
plt.ylabel('Gerçek')
plt.title('Confusion Matrix - Decision Trees (RFE)')
plt.show()
# Out:
# Decision Trees - Eğitim Verileri - Accuracy: 0.9977138824107034
# Decision Trees - Eğitim Verileri - Precision: 0.9986000933271115
# Decision Trees - Eğitim Verileri - Recall: 0.9361329833770778
# Decision Trees - Eğitim Verileri - F1 Score: 0.9663580943779634
# Decision Trees - Test Verileri - Accuracy: 0.9679656336299478
# Decision Trees - Test Verileri - Precision: 0.5380530973451327
# Decision Trees - Test Verileri - Recall: 0.5380530973451327
# Decision Trees - Test Verileri - F1 Score: 0.5380530973451327

# %%
# Verileri ölçeklendirin (Naive Bayes için gerekli değil, ancak yine de uygulayabiliriz)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Naive Bayes modelini oluşturun ve eğitin
nb_model = GaussianNB()
nb_model.fit(X_train_scaled, y_train)

# Eğitim verileri üzerinde tahmin yapın
y_train_pred = nb_model.predict(X_train_scaled)

# Test verileri üzerinde tahmin yapın
y_test_pred = nb_model.predict(X_test_scaled)

# Performans metriklerini hesaplayın
train_accuracy = accuracy_score(y_train, y_train_pred)
test_accuracy = accuracy_score(y_test, y_test_pred)
train_precision = precision_score(y_train, y_train_pred)
test_precision = precision_score(y_test, y_test_pred)
train_recall = recall_score(y_train, y_train_pred)
test_recall = recall_score(y_test, y_test_pred)
train_f1 = f1_score(y_train, y_train_pred)
test_f1 = f1_score(y_test, y_test_pred)

print(f'Naive Bayes - Eğitim Verileri - Accuracy: {train_accuracy}')
print(f'Naive Bayes - Eğitim Verileri - Precision: {train_precision}')
print(f'Naive Bayes - Eğitim Verileri - Recall: {train_recall}')
print(f'Naive Bayes - Eğitim Verileri - F1 Score: {train_f1}')

print(f'Naive Bayes - Test Verileri - Accuracy: {test_accuracy}')
print(f'Naive Bayes - Test Verileri - Precision: {test_precision}')
print(f'Naive Bayes - Test Verileri - Recall: {test_recall}')
print(f'Naive Bayes - Test Verileri - F1 Score: {test_f1}')

# Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_test_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Tahmin Edilen')
plt.ylabel('Gerçek')
plt.title('Confusion Matrix - Naive Bayes (Chi2)')
plt.show()
# Out:
# Naive Bayes - Eğitim Verileri - Accuracy: 0.9687308211611636
# Naive Bayes - Eğitim Verileri - Precision: 0.6321961620469083
# Naive Bayes - Eğitim Verileri - Recall: 0.2594050743657043
# Naive Bayes - Eğitim Verileri - F1 Score: 0.36786600496277916
# Naive Bayes - Test Verileri - Accuracy: 0.968640687327401
# Naive Bayes - Test Verileri - Precision: 0.6088709677419355
# Naive Bayes - Test Verileri - Recall: 0.2672566371681416
# Naive Bayes - Test Verileri - F1 Score: 0.3714637146371464

# %%
# Verileri ölçeklendirin (Naive Bayes için gerekli değil, ancak yine de uygulayabiliriz)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train1)
X_test_scaled = scaler.transform(X_test1)

# Naive Bayes modelini oluşturun ve eğitin
nb_model = GaussianNB()
nb_model.fit(X_train_scaled, y_train1)

# Eğitim verileri üzerinde tahmin yapın
y_train_pred = nb_model.predict(X_train_scaled)

# Test verileri üzerinde tahmin yapın
y_test_pred = nb_model.predict(X_test_scaled)

# Performans metriklerini hesaplayın
train_accuracy = accuracy_score(y_train1, y_train_pred)
test_accuracy = accuracy_score(y_test1, y_test_pred)
train_precision = precision_score(y_train1, y_train_pred)
test_precision = precision_score(y_test1, y_test_pred)
train_recall = recall_score(y_train1, y_train_pred)
test_recall = recall_score(y_test1, y_test_pred)
train_f1 = f1_score(y_train1, y_train_pred)
test_f1 = f1_score(y_test1, y_test_pred)

print(f'Naive Bayes - Eğitim Verileri - Accuracy: {train_accuracy}')
print(f'Naive Bayes - Eğitim Verileri - Precision: {train_precision}')
print(f'Naive Bayes - Eğitim Verileri - Recall: {train_recall}')
print(f'Naive Bayes - Eğitim Verileri - F1 Score: {train_f1}')

print(f'Naive Bayes - Test Verileri - Accuracy: {test_accuracy}')
print(f'Naive Bayes - Test Verileri - Precision: {test_precision}')
print(f'Naive Bayes - Test Verileri - Recall: {test_recall}')
print(f'Naive Bayes - Test Verileri - F1 Score: {test_f1}')

# Confusion Matrix
conf_matrix = confusion_matrix(y_test1, y_test_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Tahmin Edilen')
plt.ylabel('Gerçek')
plt.title('Confusion Matrix - Naive Bayes (Correlation)')
plt.show()
# Out:
# Naive Bayes - Eğitim Verileri - Accuracy: 0.9694979747146188
# Naive Bayes - Eğitim Verileri - Precision: 0.6950261780104712
# Naive Bayes - Eğitim Verileri - Recall: 0.23228346456692914
# Naive Bayes - Eğitim Verileri - F1 Score: 0.3481967213114754
# Naive Bayes - Test Verileri - Accuracy: 0.9705431113838601
# Naive Bayes - Test Verileri - Precision: 0.6976744186046512
# Naive Bayes - Test Verileri - Recall: 0.26548672566371684
# Naive Bayes - Test Verileri - F1 Score: 0.38461538461538464

# %%
# Verileri ölçeklendirin (Naive Bayes için gerekli değil, ancak yine de uygulayabiliriz)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train2)
X_test_scaled = scaler.transform(X_test2)

# Naive Bayes modelini oluşturun ve eğitin
nb_model = GaussianNB()
nb_model.fit(X_train_scaled, y_train2)

# Eğitim verileri üzerinde tahmin yapın
y_train_pred = nb_model.predict(X_train_scaled)

# Test verileri üzerinde tahmin yapın
y_test_pred = nb_model.predict(X_test_scaled)

# Performans metriklerini hesaplayın
train_accuracy = accuracy_score(y_train2, y_train_pred)
test_accuracy = accuracy_score(y_test2, y_test_pred)
train_precision = precision_score(y_train2, y_train_pred)
test_precision = precision_score(y_test2, y_test_pred)
train_recall = recall_score(y_train2, y_train_pred)
test_recall = recall_score(y_test2, y_test_pred)
train_f1 = f1_score(y_train2, y_train_pred)
test_f1 = f1_score(y_test2, y_test_pred)

print(f'Naive Bayes - Eğitim Verileri - Accuracy: {train_accuracy}')
print(f'Naive Bayes - Eğitim Verileri - Precision: {train_precision}')
print(f'Naive Bayes - Eğitim Verileri - Recall: {train_recall}')
print(f'Naive Bayes - Eğitim Verileri - F1 Score: {train_f1}')

print(f'Naive Bayes - Test Verileri - Accuracy: {test_accuracy}')
print(f'Naive Bayes - Test Verileri - Precision: {test_precision}')
print(f'Naive Bayes - Test Verileri - Recall: {test_recall}')
print(f'Naive Bayes - Test Verileri - F1 Score: {test_f1}')

# Confusion Matrix
conf_matrix = confusion_matrix(y_test2, y_test_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Tahmin Edilen')
plt.ylabel('Gerçek')
plt.title('Confusion Matrix - Naive Bayes (RFE)')
plt.show()
# Out:
# Naive Bayes - Eğitim Verileri - Accuracy: 0.969666748496379
# Naive Bayes - Eğitim Verileri - Precision: 0.7003891050583657
# Naive Bayes - Eğitim Verileri - Recall: 0.23622047244094488
# Naive Bayes - Eğitim Verileri - F1 Score: 0.35328753680078506
# Naive Bayes - Test Verileri - Accuracy: 0.9701749002761584
# Naive Bayes - Test Verileri - Precision: 0.6820276497695853
# Naive Bayes - Test Verileri - Recall: 0.26194690265486725
# Naive Bayes - Test Verileri - F1 Score: 0.37851662404092073

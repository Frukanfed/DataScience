# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Chi2 veri setini yükleyin
chi2_train_df = pd.read_csv('updated_data/chi2_training.csv')
chi2_test_df = pd.read_csv('updated_data/chi2_testing.csv')

# Eğitim verileri için öznitelikler ve hedef değişkeni ayırın
X_train = chi2_train_df.drop('target', axis=1)
y_train = chi2_train_df['target']

# Test verileri için öznitelikler ve hedef değişkeni ayırın
X_test = chi2_test_df.drop('target', axis=1)
y_test = chi2_test_df['target']

correlation_train_df = pd.read_csv('updated_data/correlation_training.csv')
correlation_test_df = pd.read_csv('updated_data/correlation_testing.csv')

# Eğitim verileri için öznitelikler ve hedef değişkeni ayırın
X_train1 = correlation_train_df.drop('target', axis=1)
y_train1 = correlation_train_df['target']

# Test verileri için öznitelikler ve hedef değişkeni ayırın
X_test1 = correlation_test_df.drop('target', axis=1)
y_test1 = correlation_test_df['target']


# Lasso veri setini yükleyin
lasso_train_df = pd.read_csv('updated_data/lasso_training.csv')
lasso_test_df = pd.read_csv('updated_data/lasso_testing.csv')

# Eğitim verileri için öznitelikler ve hedef değişkeni ayırın
X_train2 = lasso_train_df.drop('target', axis=1)
y_train2 = lasso_train_df['target']

# Test verileri için öznitelikler ve hedef değişkeni ayırın
X_test2 = lasso_test_df.drop('target', axis=1)
y_test2 = lasso_test_df['target']

# %%
# Verileri ölçeklendirin (Naive Bayes için gerekli değil, ancak yine de uygulayabiliriz)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Naive Bayes modelini oluşturun ve eğitin
nb_model = GaussianNB()
nb_model.fit(X_train_scaled, y_train)

# Eğitim verileri üzerinde tahmin yapın
y_train_pred = nb_model.predict(X_train_scaled)

# Test verileri üzerinde tahmin yapın
y_test_pred = nb_model.predict(X_test_scaled)

# Performans metriklerini hesaplayın
train_accuracy = accuracy_score(y_train, y_train_pred)
test_accuracy = accuracy_score(y_test, y_test_pred)
train_precision = precision_score(y_train, y_train_pred)
test_precision = precision_score(y_test, y_test_pred)
train_recall = recall_score(y_train, y_train_pred)
test_recall = recall_score(y_test, y_test_pred)
train_f1 = f1_score(y_train, y_train_pred)
test_f1 = f1_score(y_test, y_test_pred)

print(f'Naive Bayes - Eğitim Verileri - Accuracy: {train_accuracy}')
print(f'Naive Bayes - Eğitim Verileri - Precision: {train_precision}')
print(f'Naive Bayes - Eğitim Verileri - Recall: {train_recall}')
print(f'Naive Bayes - Eğitim Verileri - F1 Score: {train_f1}')

print(f'Naive Bayes - Test Verileri - Accuracy: {test_accuracy}')
print(f'Naive Bayes - Test Verileri - Precision: {test_precision}')
print(f'Naive Bayes - Test Verileri - Recall: {test_recall}')
print(f'Naive Bayes - Test Verileri - F1 Score: {test_f1}')

# Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_test_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Tahmin Edilen')
plt.ylabel('Gerçek')
plt.title('Confusion Matrix - Naive Bayes (Chi2)')
plt.show()
# Out:
# Naive Bayes - Eğitim Verileri - Accuracy: 0.8224789915966386
# Naive Bayes - Eğitim Verileri - Precision: 0.841995841995842
# Naive Bayes - Eğitim Verileri - Recall: 0.8132530120481928
# Naive Bayes - Eğitim Verileri - F1 Score: 0.8273748723186926
# Naive Bayes - Test Verileri - Accuracy: 0.8529411764705882
# Naive Bayes - Test Verileri - Precision: 0.8692307692307693
# Naive Bayes - Test Verileri - Recall: 0.8625954198473282
# Naive Bayes - Test Verileri - F1 Score: 0.8659003831417624

# %%
# Verileri ölçeklendirin (Naive Bayes için gerekli değil, ancak yine de uygulayabiliriz)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train1)
X_test_scaled = scaler.transform(X_test1)

# Naive Bayes modelini oluşturun ve eğitin
nb_model = GaussianNB()
nb_model.fit(X_train_scaled, y_train1)

# Eğitim verileri üzerinde tahmin yapın
y_train_pred = nb_model.predict(X_train_scaled)

# Test verileri üzerinde tahmin yapın
y_test_pred = nb_model.predict(X_test_scaled)

# Performans metriklerini hesaplayın
train_accuracy = accuracy_score(y_train1, y_train_pred)
test_accuracy = accuracy_score(y_test1, y_test_pred)
train_precision = precision_score(y_train1, y_train_pred)
test_precision = precision_score(y_test1, y_test_pred)
train_recall = recall_score(y_train1, y_train_pred)
test_recall = recall_score(y_test1, y_test_pred)
train_f1 = f1_score(y_train1, y_train_pred)
test_f1 = f1_score(y_test1, y_test_pred)

print(f'Naive Bayes - Eğitim Verileri - Accuracy: {train_accuracy}')
print(f'Naive Bayes - Eğitim Verileri - Precision: {train_precision}')
print(f'Naive Bayes - Eğitim Verileri - Recall: {train_recall}')
print(f'Naive Bayes - Eğitim Verileri - F1 Score: {train_f1}')

print(f'Naive Bayes - Test Verileri - Accuracy: {test_accuracy}')
print(f'Naive Bayes - Test Verileri - Precision: {test_precision}')
print(f'Naive Bayes - Test Verileri - Recall: {test_recall}')
print(f'Naive Bayes - Test Verileri - F1 Score: {test_f1}')

# Confusion Matrix
conf_matrix = confusion_matrix(y_test1, y_test_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Tahmin Edilen')
plt.ylabel('Gerçek')
plt.title('Confusion Matrix - Naive Bayes (Correlation)')
plt.show()
# Out:
# Naive Bayes - Eğitim Verileri - Accuracy: 0.8172268907563025
# Naive Bayes - Eğitim Verileri - Precision: 0.8360995850622407
# Naive Bayes - Eğitim Verileri - Recall: 0.8092369477911646
# Naive Bayes - Eğitim Verileri - F1 Score: 0.8224489795918367
# Naive Bayes - Test Verileri - Accuracy: 0.8361344537815126
# Naive Bayes - Test Verileri - Precision: 0.8484848484848485
# Naive Bayes - Test Verileri - Recall: 0.8549618320610687
# Naive Bayes - Test Verileri - F1 Score: 0.8517110266159695

# %%
# Verileri ölçeklendirin (Naive Bayes için gerekli değil, ancak yine de uygulayabiliriz)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train2)
X_test_scaled = scaler.transform(X_test2)

# Naive Bayes modelini oluşturun ve eğitin
nb_model = GaussianNB()
nb_model.fit(X_train_scaled, y_train2)

# Eğitim verileri üzerinde tahmin yapın
y_train_pred = nb_model.predict(X_train_scaled)

# Test verileri üzerinde tahmin yapın
y_test_pred = nb_model.predict(X_test_scaled)

# Performans metriklerini hesaplayın
train_accuracy = accuracy_score(y_train2, y_train_pred)
test_accuracy = accuracy_score(y_test2, y_test_pred)
train_precision = precision_score(y_train2, y_train_pred)
test_precision = precision_score(y_test2, y_test_pred)
train_recall = recall_score(y_train2, y_train_pred)
test_recall = recall_score(y_test2, y_test_pred)
train_f1 = f1_score(y_train2, y_train_pred)
test_f1 = f1_score(y_test2, y_test_pred)

print(f'Naive Bayes - Eğitim Verileri - Accuracy: {train_accuracy}')
print(f'Naive Bayes - Eğitim Verileri - Precision: {train_precision}')
print(f'Naive Bayes - Eğitim Verileri - Recall: {train_recall}')
print(f'Naive Bayes - Eğitim Verileri - F1 Score: {train_f1}')

print(f'Naive Bayes - Test Verileri - Accuracy: {test_accuracy}')
print(f'Naive Bayes - Test Verileri - Precision: {test_precision}')
print(f'Naive Bayes - Test Verileri - Recall: {test_recall}')
print(f'Naive Bayes - Test Verileri - F1 Score: {test_f1}')

# Confusion Matrix
conf_matrix = confusion_matrix(y_test2, y_test_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Tahmin Edilen')
plt.ylabel('Gerçek')
plt.title('Confusion Matrix - Naive Bayes (Lasso)')
plt.show()
# Out:
# Naive Bayes - Eğitim Verileri - Accuracy: 0.8224789915966386
# Naive Bayes - Eğitim Verileri - Precision: 0.8448637316561844
# Naive Bayes - Eğitim Verileri - Recall: 0.8092369477911646
# Naive Bayes - Eğitim Verileri - F1 Score: 0.8266666666666667
# Naive Bayes - Test Verileri - Accuracy: 0.8235294117647058
# Naive Bayes - Test Verileri - Precision: 0.8503937007874016
# Naive Bayes - Test Verileri - Recall: 0.8244274809160306
# Naive Bayes - Test Verileri - F1 Score: 0.8372093023255814
